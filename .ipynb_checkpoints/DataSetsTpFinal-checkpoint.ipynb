# %% [markdown]
# # DEFINICIÓN DE LA FUENTE DE INFORMACIÓN

# %% [markdown]
# ## Grupo 7:
# * Meritello, Bartolomé
# * Mornaghi, José
# * Saavedra, Lucas
# * Pascual, Juan

# %% [markdown]
# ### Presentar (máximo) tres sets de datos que puedan ser usados como fuente de información para sus proyectos finales.

# %%
import pandas as pd

# %% [markdown]
# 1) Stroke dataset: El objetivo del trabajo consistiría en clasificar si un individuo sufrirá un Stroke o no. De este modo la variable objetivo es: Stroke

# %% [markdown]
# Fuente: https://www.kaggle.com/fedesoriano/stroke-prediction-dataset/version/1

# %%
dfStroke = pd.read_csv('stroke.csv')
dfStroke
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 dfStroke = pd.read_csv('stroke.csv')
#       2 dfStroke
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# 2) Bankruptcy dataset: El objetivo del trabajo consistiría en clasificar si un compañía declarará bancarota o no. De este modo a variable objetivo es: Bankrupt?

# %% [markdown]
# Fuente: https://www.kaggle.com/fedesoriano/company-bankruptcy-prediction

# %%
dfBankruptcy = pd.read_csv('bankruptcy.csv')
dfBankruptcy
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %% [markdown]
# 3) Bikes dataset:  El objetivo del trabajo consistiría en predecir el numero promedio de bicis en una hora tipo para ayudar a la empresa en la distribución de bicicletas según los puntos de servicio. De este modo la variable objetivo es: bikes_per_hour

# %% [markdown]
# Fuente: https://www.soa.org/globalassets/assets/files/edu/2020/2020-12-7-exam-pa-project-statement.pdf

# %%
dfBikes = pd.read_csv('bikes.csv')
dfBikes
# Out:
#        season  year  hour  holiday  weekday  weathersit  temp  humidity  \
# 0           1     0     0        0        6           1  0.24      0.81
# 1           1     0     1        0        6           1  0.22      0.80
# 2           1     0     2        0        6           1  0.22      0.80
# 3           1     0     3        0        6           1  0.24      0.75
# 4           1     0     4        0        6           1  0.24      0.75
# ...       ...   ...   ...      ...      ...         ...   ...       ...
# 17371       1     1    19        0        1           2  0.26      0.60
# 17372       1     1    20        0        1           2  0.26      0.60
# 17373       1     1    21        0        1           1  0.26      0.60
# 17374       1     1    22        0        1           1  0.26      0.56
# 17375       1     1    23        0        1           1  0.26      0.65
#
#        windspeed  bikes_per_hour
# 0         0.0000              16
# 1         0.0000              40
# ...
